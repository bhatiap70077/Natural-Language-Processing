# %% [markdown]
# <a href="https://colab.research.google.com/github/bhatiap70077/Natural-Language-Processing/blob/main/Assignment_1E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.1.66)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.3.0)

# %%
# !pip install nlpretext
# Out:
# Requirement already satisfied: nlpretext in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: numpy>1.15.4 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.21.5)
# Requirement already satisfied: nltk<3.6,>=3.4.2 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (3.5)
# Requirement already satisfied: distributed>=2021.5.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (2022.2.0)
# Collecting spacy>=3.0.5
#   Using cached spacy-3.2.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
# Requirement already satisfied: sacremoses>=0.0.13 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (0.0.47)
# Requirement already satisfied: emoji>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.6.3)
# Requirement already satisfied: flashtext>=2.7 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (2.7)
# Requirement already satisfied: importlib_metadata>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (4.11.0)
# Requirement already satisfied: pyarrow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (6.0.1)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (6.1)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.3.5)
# Requirement already satisfied: nlpaug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.1.10)
# Collecting thinc>=8.0.4
#   Using cached thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
# Requirement already satisfied: pillow>=8.2.1 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (9.0.1)
# Requirement already satisfied: dask[complete]>=2021.5.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (2022.2.0)
# Requirement already satisfied: ftfy>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (6.1.1)
# Requirement already satisfied: stop-words>=2018.7.23 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (2018.7.23)
# Requirement already satisfied: phonenumbers>=8.10.12 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (8.12.43)
# Requirement already satisfied: fastparquet>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (0.8.0)
# Requirement already satisfied: rich>=10.1.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (11.2.0)
# Requirement already satisfied: regex>=2019.8.19 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (2019.12.20)
# Requirement already satisfied: typer[all]>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (0.4.0)
# Requirement already satisfied: scikit-learn>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.0.2)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (3.0.4)
# Requirement already satisfied: mosestokenizer>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from nlpretext) (1.2.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (2.0.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (0.11.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (21.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (2022.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (1.2.0)
# Requirement already satisfied: bokeh>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (2.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=2021.5.0->nlpretext) (2.11.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (1.0.3)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (5.4.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (57.4.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (7.1.2)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2021.5.0->nlpretext) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.1.1->dask[complete]>=2021.5.0->nlpretext) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=2.1.1->dask[complete]>=2021.5.0->nlpretext) (2.8.2)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet>=0.4.1->nlpretext) (2.5.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy>=4.2.0->nlpretext) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib_metadata>=1.6.0->nlpretext) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->dask[complete]>=2021.5.0->nlpretext) (2.0.1)
# Requirement already satisfied: toolwrapper in /usr/local/lib/python3.7/dist-packages (from mosestokenizer>=1.1.0->nlpretext) (2.1.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from mosestokenizer>=1.1.0->nlpretext) (0.6.2)
# Requirement already satisfied: openfile in /usr/local/lib/python3.7/dist-packages (from mosestokenizer>=1.1.0->nlpretext) (0.0.7)
# Requirement already satisfied: uctools in /usr/local/lib/python3.7/dist-packages (from mosestokenizer>=1.1.0->nlpretext) (1.3.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from nlpaug>=1.0.1->nlpretext) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<3.6,>=3.4.2->nlpretext) (4.62.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<3.6,>=3.4.2->nlpretext) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->dask[complete]>=2021.5.0->nlpretext) (3.0.7)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->nlpretext) (2021.3)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[complete]>=2021.5.0->nlpretext) (0.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=2.1.1->dask[complete]>=2021.5.0->nlpretext) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug>=1.0.1->nlpretext) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug>=1.0.1->nlpretext) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->nlpaug>=1.0.1->nlpretext) (2021.10.8)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.1.0->nlpretext) (2.6.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.1.0->nlpretext) (0.4.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.1.0->nlpretext) (0.9.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.2->nlpretext) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.23.2->nlpretext) (3.1.0)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (0.9.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (0.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (1.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (0.6.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.5->nlpretext) (1.0.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy>=3.0.5->nlpretext) (5.2.1)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.3.2->nlpretext) (1.4.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2021.5.0->nlpretext) (1.0.1)
# Installing collected packages: catalogue, srsly, thinc, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.5
#     Uninstalling spacy-2.3.5:
#       Successfully uninstalled spacy-2.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.2.2 which is incompatible.
# Successfully installed catalogue-2.0.6 spacy-3.2.2 srsly-2.4.2 thinc-8.0.13

# %%
# !pip install nltk

# !pip install spacy==2.3.5

# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz

# !pip install pyresparser
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.62.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk) (2019.12.20)
# Collecting spacy==2.3.5
#   Using cached spacy-2.3.5-cp37-cp37m-manylinux2014_x86_64.whl (10.4 MB)
# Collecting srsly<1.1.0,>=1.0.2
#   Using cached srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.21.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (0.9.0)
# Collecting thinc<7.5.0,>=7.4.1
#   Using cached thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (1.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.3.5) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.3.5) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (1.25.11)
# Installing collected packages: srsly, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.6
#     Uninstalling catalogue-2.0.6:
#       Successfully uninstalled catalogue-2.0.6
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.13
#     Uninstalling thinc-8.0.13:
#       Successfully uninstalled thinc-8.0.13
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.2.2
#     Uninstalling spacy-3.2.2:
#       Successfully uninstalled spacy-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nlpretext 1.1.0 requires spacy>=3.0.5, but you have spacy 2.3.5 which is incompatible.
# nlpretext 1.1.0 requires thinc>=8.0.4, but you have thinc 7.4.5 which is incompatible.
# Successfully installed catalogue-1.0.0 spacy-2.3.5 srsly-1.0.5 thinc-7.4.5
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.3 MB/s
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==2.3.1) (2.3.5)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (7.4.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.9.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.21.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en-core-web-sm==2.3.1) (2021.10.8)
# Requirement already satisfied: pyresparser in /usr/local/lib/python3.7/dist-packages (1.0.6)
# Requirement already satisfied: wasabi>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.9.0)
# Requirement already satisfied: blis>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.4.1)
# Requirement already satisfied: srsly>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.0.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.15.0)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.25.11)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.21.5)
# Requirement already satisfied: preshed>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.0.6)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.23.0)
# Requirement already satisfied: spacy>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.3.5)
# Requirement already satisfied: pdfminer.six>=20181108 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (20211012)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (1.3.5)
# Requirement already satisfied: pyrsistent>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.18.1)
# Requirement already satisfied: docx2txt>=0.7 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (0.8)
# Requirement already satisfied: nltk>=3.4.3 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.5)
# Requirement already satisfied: pycryptodome>=3.8.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.14.1)
# Requirement already satisfied: certifi>=2019.6.16 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2021.10.8)
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: cymem>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.0.6)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (4.62.3)
# Requirement already satisfied: thinc>=7.0.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (7.4.5)
# Requirement already satisfied: pytz>=2019.1 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2021.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.10)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (21.4.0)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (3.0.4)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pyresparser) (2.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (5.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (3.10.0.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->pyresparser) (4.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.1->pyresparser) (3.7.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (7.1.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (2019.12.20)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.4.3->pyresparser) (1.1.0)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.7/dist-packages (from pdfminer.six>=20181108->pyresparser) (36.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from preshed>=2.0.1->pyresparser) (1.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (1.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.1.4->pyresparser) (57.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography->pdfminer.six>=20181108->pyresparser) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography->pdfminer.six>=20181108->pyresparser) (2.21)

# %%
#Importing Libraries
import re
import contractions
from nlpretext import Preprocessor
import nltk
import pandas
import spacy
from nltk import ngrams
import nltk
from nltk.util import ngrams
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from spacy import displacy
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
text="""         Jack and jill have made a delicious,       dish.
Then they started to play some12 game! and jill has attahacd# [a] photo frame to the straight9 wall
and swung on sea-saw. She was very happy. After the game, they both went to central London to enjoy some fast food."""

# %%
class Text_Preprocess:
    """
    This class(Text_Ptreprocess) object contains functions to pre-process the data. 
    Functions inside classes : 
    ------------------------------
    1) exp_contractions()--> to expand contractions
    2) spec_char()-->        to remove spcecial characters and extra spaces
    3) simp_dig_email()----> Simplifying the digits and emails.
    4) tokenization()-->     to breakdown the text into tokens.
    5) Stop words()--------->to remove the stop words.
    """
    def exp_contractions(self,text:str)->str:
        '''
        This method expands the contractions in the given text
            Input arguments : text (Here the input is the text and this function expands the contractions inside the text 
            For Ex: doesn't changes to does not)
            -------------------------------------------------------------------------------------------------------------
            Returns: We get the expanded text
            --------
            '''
            # creating an empty list
        expanded_words = []    
        for word in text.split():
            ''''''
            # using contractions.fix to expand the shotened words
            expanded_words.append(contractions.fix(word))   

        expanded_text = ' '.join(expanded_words)
        return expanded_text
    '''
    Process finished with exit code 0
    '''
    
    def spec_char(self,text:str)->str:
        '''This method removes the special characters along with extra spaces
        Input arguments: text ( In this function all the special characters will be removed and extra spaces will be cleared )
        ---------------     
        Returns: The final text will have cleared special characters.'''
        preprocessor = Preprocessor()
        Formatted_Text = re.sub(r"[^A-Za-z]+", ' ', text)
        '''The regular expression written above returns a match if the string contains characters except specified.'''
        spec_text = preprocessor.run(Formatted_Text)
        return spec_text
        '''It returns the text clearing special characters.'''
   
    def simp_dig_email(self,text:str)->str:
        ''' 
        This method simplifies the digits and emails using regular expressions.
              Input arguments: text (In this function the digits and email will be cleared by using certain patterns)
              ---------------     
              Returns:  We get simplified text.
        '''
        preprocessor = Preprocessor()
        Formatted_Text = re.sub(r"-@]+", ' ', text)
        simp_text = preprocessor.run(Formatted_Text)
        return simp_text
    
    def tokenization(self,text:str)->list:
        ''' In this function the whole text will be divided into tokens.
                By tokenization we can transform indivisible assets into tokens'''
        tokenized_text = nltk.tokenize.word_tokenize(text)
        return tokenized_text
    
    def stopwords(self,tokens:list, method:str)->list:
        ''' 
        Stopwords are a set of commonly used words such as is, the, are etc.. 
        Input
        -----
        text file as string
        
        Returns
        ------
        list of words without stopwords
        '''
        nltk.download('stopwords')
        list_of_stop_words = stopwords.words('english')

        list_of_stop_words[1:10]

        token_without_stopwords = [i for i in tokens if i not in list_of_stop_words]
        string = ' '.join(map(str,token_without_stopwords))    
        return string
        
    def Part(self,tokens:list):
        tokenized_text = nltk.tokenize.word_tokenize(tokens)
        part_of_speech = nltk.pos_tag(tokenized_text)
        return part_of_speech
    
    
    def name_ent_rec(self,tokens:list):
        nlp = spacy.load('en_core_web_sm')
        # load data
        
        doc = nlp(tokens)
 
        # print entities
        for ent in doc.ents:
            print(ent.text, ent.label_) 
            
    def ngram(self,tokens):
        NGRAMS=ngrams(sequence=nltk.word_tokenize(tokens), n=5)
        for grams in NGRAMS:
            print(grams)
 
 
    def get_preprocessed_text(self):
        con_text = self.exp_contractions(text)
        special_text = self.spec_char(con_text)
        simplify_text = self.simp_dig_email(special_text)
        token_text = self.tokenization(simplify_text)
        stopword_text = self.stopwords(token_text, 'english')
        partofspeech = self.Part(stopword_text)
        ner = self.name_ent_rec(stopword_text)
        ng = self.ngram(stopword_text)
        return (ner,ng,partofspeech)

# %%
#Class Object
"""
Main Class
"""
Class_obj = Text_Preprocess()

Class_obj.get_preprocessed_text()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Jack PERSON
# London GPE
# ('Jack', 'jill', 'made', 'delicious', 'dish')
# ('jill', 'made', 'delicious', 'dish', 'Then')
# ('made', 'delicious', 'dish', 'Then', 'started')
# ('delicious', 'dish', 'Then', 'started', 'play')
# ('dish', 'Then', 'started', 'play', 'game')
# ('Then', 'started', 'play', 'game', 'jill')
# ('started', 'play', 'game', 'jill', 'attahacd')
# ('play', 'game', 'jill', 'attahacd', 'photo')
# ('game', 'jill', 'attahacd', 'photo', 'frame')
# ('jill', 'attahacd', 'photo', 'frame', 'straight')
# ('attahacd', 'photo', 'frame', 'straight', 'wall')
# ('photo', 'frame', 'straight', 'wall', 'swung')
# ('frame', 'straight', 'wall', 'swung', 'sea')
# ('straight', 'wall', 'swung', 'sea', 'saw')
# ('wall', 'swung', 'sea', 'saw', 'She')
# ('swung', 'sea', 'saw', 'She', 'happy')
# ('sea', 'saw', 'She', 'happy', 'After')
# ('saw', 'She', 'happy', 'After', 'game')
# ('She', 'happy', 'After', 'game', 'went')
# ('happy', 'After', 'game', 'went', 'central')
# ('After', 'game', 'went', 'central', 'London')
# ('game', 'went', 'central', 'London', 'enjoy')
# ('went', 'central', 'London', 'enjoy', 'fast')
# ('central', 'London', 'enjoy', 'fast', 'food')
# (None,
#  None,
#  [('Jack', 'NNP'),
#   ('jill', 'NN'),
#   ('made', 'VBD'),
#   ('delicious', 'JJ'),
#   ('dish', 'JJ'),
#   ('Then', 'RB'),
#   ('started', 'VBD'),
#   ('play', 'NNS'),
#   ('game', 'NN'),
#   ('jill', 'NN'),
#   ('attahacd', 'VBZ'),
#   ('photo', 'NN'),
#   ('frame', 'NN'),
#   ('straight', 'VBD'),
#   ('wall', 'NN'),
#   ('swung', 'NN'),
#   ('sea', 'NN'),
#   ('saw', 'VBD'),
#   ('She', 'PRP'),
#   ('happy', 'JJ'),
#   ('After', 'IN'),
#   ('game', 'NN'),
#   ('went', 'VBD'),
#   ('central', 'JJ'),
#   ('London', 'NNP'),
#   ('enjoy', 'NN'),
#   ('fast', 'VBD'),
#   ('food', 'NN')])
